# %%
import pandas as pd

# %%
import seaborn as sns

# %%
tips= sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",style="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df=pd.read_csv('Titanic Train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(data=df,x="Pclass",y="Age")
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
#this black line show confidence interwal

# %%
sns.barplot(data=df,x="Pclass",y="Fare")
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(data=df,x="Pclass",y="Fare",hue="Sex")
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(data=df,x="Pclass",y="Age",hue="Sex")
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # Box Plot(Numerical-categorical)

# %%
#xaxis is for categorical data and y is for numerical data

# %%
sns.boxplot(data=df,x="Sex",y="Age")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#outlier is present in male (the black dot)

# %%
sns.boxplot(data=df,x="Sex",y='Age',hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#in male young age is has more survival and in female old age has more survival

# %% [markdown]
# # Distplot(Numerical-Categorical)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_25748\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df[df["Survived"]==0]["Age"])
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_25748\500049129.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["Survived"]==0]["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#this is pdf of people who dont survived

# %%
sns.distplot(df[df["Survived"]==0]["Age"],hist=False)
sns.distplot(df[df["Survived"]==1]["Age"],hist=False)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_25748\1110306383.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["Survived"]==0]["Age"],hist=False)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_25748\1110306383.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
## orange=p(survived) and P(not survived)= Blue
##for the age below 0 probobility of surviving is more than the probability of 
#dying

# %%
## from the age 15-30 P(dying) is more

# %% [markdown]
# # HeatMap(Categorical-Categorical)

# %%
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(df.groupby('Pclass')['Survived'].mean
# Out:
#   Cell In[45], line 1
#     (df.groupby('Pclass')['Survived'].mean
#                                           ^
# SyntaxError: incomplete input

# %% [markdown]
# # ClusterMap (Categorical-Categorical)

# %%
pd.crosstab(df['SibSp'],df['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.clustermap(pd.crosstab(df['SibSp'],df['Survived']))

# %%
sns.clustermap(pd.crosstab(df['Parch'],df['Survived']))

# %% [markdown]
# # Pairplot

# %%
## plot multiple scatterplot

# %%
sns.pairplot(df)
# Out:
# C:\Users\rahul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips)
# Out:
# C:\Users\rahul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # LinePlot(Numerical-Numerical)

# %%
##this is used when the quantity on the x axis is time based numerical data

# %%
df2=pd.read_csv('population US')

# %%
df2.head()
# Out:
#    Unnamed: 0 ID Nation         Nation  Year  Population
# 0           0   01000US  United States  2021   329725481
# 1           1   01000US  United States  2020   326569308
# 2           2   01000US  United States  2019   324697795
# 3           3   01000US  United States  2018   322903030
# 4           4   01000US  United States  2017   321004407

# %%
sns.lineplot(df2['Year'],df2['Population'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 sns.lineplot(df2['Year'],df2['Population'])
#
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.lineplot(data=df2,x='Year',y='Population')
# Out:
# <Axes: xlabel='Year', ylabel='Population'>
