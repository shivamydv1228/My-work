# %%
import pandas as pd

# %%
df=pd.read_csv('Titanic Train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns

# %%
df1=pd.read_csv('airlines.csv')

# %%
df1
# Out:
#       Airline ID                                          Name  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# ...          ...                                           ...
# 6157       21248                                   GX Airlines
# 6158       21251                        Lynx Aviation (L3/SSX)
# 6159       21268                               Jetgo Australia
# 6160       21270                                  Air Carnival
# 6161       21317                                 Svyaz Rossiya
#
#                   Alias IATA ICAO         Callsign         Country Active
# 0                    \N    -  NaN               \N              \N      Y
# ...

# %%
df2=pd.read_csv('population US')

# %%
df2
# Out:
#    Unnamed: 0 ID Nation         Nation  Year  Population
# 0           0   01000US  United States  2021   329725481
# 1           1   01000US  United States  2020   326569308
# 2           2   01000US  United States  2019   324697795
# 3           3   01000US  United States  2018   322903030
# 4           4   01000US  United States  2017   321004407
# 5           5   01000US  United States  2016   318558162
# 6           6   01000US  United States  2015   316515021
# 7           7   01000US  United States  2014   314107084
# 8           8   01000US  United States  2013   311536594

# %%
sns.scatterplot(df2['Population'],df2['Year'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.scatterplot(df2['Population'],df2['Year'])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
tips= sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(tips['total_bill'],tips['tip'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.scatterplot(tips['total_bill'],tips['tip'])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex")
#
# NameError: name 'sns' is not defined

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="sex",style="smoker",size="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df, x="Pclass", y="Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# # Bar plot

# %%
# it is for numerical and categorical dataset

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(df["Pclass"],df['Age'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.barplot(df["Pclass"],df['Age'])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.barplot(data=df, x="Pclass", y="Age")
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(data=df, x="Pclass", y="Fare",hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(data=df, x="Pclass", y="Age",hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
