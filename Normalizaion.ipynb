# %%
import numpy as np #linear algebra
import pandas as pd # data processing 

import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
sns.kdeplot(df['EstimatedSalary'])
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Density'>

# %%
color_dist= {0:'red',1:"green"}
sns.scatterplot(df['Age'],df['EstimatedSalary'],hue=df['Purchased'],palette=color_dist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 color_dist= {0:'red',1:"green"}
# ----> 2 sns.scatterplot(df['Age'],df['EstimatedSalary'],hue=df['Purchased'],palette=color_dist)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 2 keyword-only arguments) were given

# %%
sns.scatterplot(data=df, x="EstimatedSalary", y="Age", hue="Purchased")
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Age'>

# %%
color_dist= {0:'red',1:"green"}
sns.scatterplot(data=df, x="EstimatedSalary", y="Age", hue="Purchased",palette=color_dist)
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Age'>

# %%
## before scaling we have to do train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop('Purchased',axis=1),
                                                df['Purchased'],
                                                test_size=0.3,
                                                random_state=0)

X_train.shape,X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
## now we do normalization i.e min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
#fit the scaler to train set, it will learn paramerter
scaler.fit(X_train)

#transform train and test sets

X_train_scaled= scaler.transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
## covert aray to dataframe

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns= X_test.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.5              0.4
# std      0.2              0.3
# min      0.0              0.0
# 25%      0.3              0.2
# 50%      0.5              0.4
# 75%      0.7              0.5
# max      1.0              1.0

# %%
##after scaling we get min=0 and max=1 in both the column

# %%
## scatter plot is same before and afer scaling

# %%
## afer scaling the range of both column come to same range (0,1)

# %%
## in min max scaling the impact of the outlier is get reduced as range reduced
